# %%
from typing import List, Dict
import arviz as az
import estival.priors as esp
from estival.sampling import tools as esamp
import plotly.graph_objects as go
import plotly.express as px
from tbdynamics.tools.utils import round_sigfig
import pandas as pd
from tbdynamics.settings import BASE_PATH, OUT_PATH
from tbdynamics.vietnam.calibration.utils import get_bcm
from plotly.subplots import make_subplots

pd.options.plotting.backend = "plotly"
# Out:
# WARNING (pytensor.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (pytensor.configdefaults): g++ not detected!  PyTensor will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set PyTensor flags cxx to an empty string.
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
def calculate_covid_cum_diff(
    params: Dict[str, float],
    idata_extract: az.InferenceData,
    cumulative_start_time: float = 2020.0,
    years: List[float] = [2021.0, 2022.0, 2025.0, 2030.0, 2035.0],
) -> Dict[str, Dict[str, pd.DataFrame]]:
    """
    Run the models for the specified scenarios, calculate cumulative diseased and death values,
    and return both the raw values and differences for detection reduction only - no covid.

    Args:
        params: Dictionary containing model parameters.
        idata_extract: InferenceData object containing the model data.
        cumulative_start_time: Year to start calculating the cumulative values.
        years: List of years for which to calculate the differences.

    Returns:
        A dictionary containing cumulative diseased and deaths, incidence, and mortality raw data for each scenario,
        as well as the differences between "detection" and "no_covid".
    """

    # Define the scenarios with scenario names as keys
    covid_configs = {
        "no_covid": {"detection_reduction": False, "contact_reduction": False},  # No reduction
        "detection": {"detection_reduction": True, "contact_reduction": False},  # Detection reduction only
    }

    scenario_results = {}

    for scenario_name, covid_effects in covid_configs.items():
        # Get the model results
        bcm = get_bcm(params, covid_effects)
        spaghetti_res = esamp.model_results_for_samples(idata_extract, bcm).results

        # Filter the results to include only the rows where the index (year) is an integer
        yearly_data = spaghetti_res.loc[
            (spaghetti_res.index >= cumulative_start_time) & (spaghetti_res.index % 1 == 0)
        ]

        # Calculate cumulative sums for each sample
        cumulative_diseased_yearly = yearly_data["incidence_raw"].cumsum()
        cumulative_deaths_yearly = yearly_data["mortality_raw"].cumsum()

        # Extract results for specified years
        cumulative_diseased_results = cumulative_diseased_yearly.loc[years]
        cumulative_deaths_results = cumulative_deaths_yearly.loc[years]

        # Store all relevant results in the dictionary under the scenario name
        scenario_results[scenario_name] = {
            "cumulative_diseased_yearly": cumulative_diseased_yearly,
            "cumulative_deaths_yearly": cumulative_deaths_yearly,
            "incidence_raw": yearly_data["incidence_raw"],
            "mortality_raw": yearly_data["mortality_raw"],
        }

    # Calculate the differences between "detection" and "no_covid" for cumulative values only
    diff_results = {
        "cumulative_diseased_yearly_diff": (
            scenario_results["detection"]["cumulative_diseased_yearly"]
            - scenario_results["no_covid"]["cumulative_diseased_yearly"]
        ),
        "cumulative_deaths_yearly_diff": (
            scenario_results["detection"]["cumulative_deaths_yearly"]
            - scenario_results["no_covid"]["cumulative_deaths_yearly"]
        ),
    }

    # Combine both raw scenario results and the differences into the final output
    return {"scenario_results": scenario_results, "diff_results": diff_results}

# %%
idata = az.from_netcdf(OUT_PATH / 'vietnam/idata/idata_detection.nc')
params = {
    "start_population_size": 2000000.0,
    "seed_time": 1805.0,
    "seed_num": 1.0,
    "seed_duration": 1.0,
}

# %%
covid_diff = calculate_covid_cum_diff(params, idata)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\computegraph\graph.py:103, in build_callable.<locals>.compute_from_params(**sources)
#     102 try:
# --> 103     out_p[node] = node_spec.evaluate(**sources)
#     104 except Exception as e:
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\computegraph\types.py:133, in Variable.evaluate(self, **sources)
#     132 def evaluate(self, **sources):
# --> 133     return sources[self.source][self.key]
#
# KeyError: 'incidence_props_pulmonary'
#
# During handling of the above exception, another exception occurred:
#
# GraphRunError                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 covid_diff = calculate_covid_cum_diff(params, idata)
#
# Cell In[2], line 33, in calculate_covid_cum_diff(params, idata_extract, cumulative_start_time, years)
#      30 for scenario_name, covid_effects in covid_configs.items():
#      31     # Get the model results
#      32     bcm = get_bcm(params, covid_effects)
# ---> 33     spaghetti_res = esamp.model_results_for_samples(idata_extract, bcm).results
#      35     # Filter the results to include only the rows where the index (year) is an integer
#      36     yearly_data = spaghetti_res.loc[
#      37         (spaghetti_res.index >= cumulative_start_time) & (spaghetti_res.index % 1 == 0)
#      38     ]
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\estival\sampling\tools.py:195, in model_results_for_samples(samples, bcm, include_extras, num_workers, exec_mode)
#     192 # samples = validate_samplecontainer(samples)
#     193 samples = bcm.sample.convert(samples)  # type: ignore
# --> 195 pres = map_parallel(get_model_results, samples.iterrows(), num_workers, mode=exec_mode)
#     197 df = pd.concat([p[1].derived_outputs for p in pres], keys=[p[0] for p in pres])
#     199 if isinstance(samples.index, pd.MultiIndex):
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\estival\utils\parallel.py:72, in map_parallel(run_func, input_iterator, n_workers, mode)
#      70     with ThreadPoolExecutor(n_workers) as pool:  # type: ignore
#      71         pres = pool.map(run_func, input_iterator)
# ---> 72         pres = [p for p in pres]
#      73 else:
#      74     raise ValueError("Mode must be one of ['thread', 'process']")
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\estival\utils\parallel.py:72, in <listcomp>(.0)
#      70     with ThreadPoolExecutor(n_workers) as pool:  # type: ignore
#      71         pres = pool.map(run_func, input_iterator)
# ---> 72         pres = [p for p in pres]
#      73 else:
#      74     raise ValueError("Mode must be one of ['thread', 'process']")
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\concurrent\futures\_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\concurrent\futures\_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\estival\sampling\tools.py:189, in model_results_for_samples.<locals>.get_model_results(sample_params)
#     178 """Run the BCM for a given set of parameters, and return its extras dictionary
#     179 (likelihood, posterior etc)
#     180
#    (...)
#     185     A tuple of SampleIndex and the ResultsData.extras dictionary
#     186 """
#     188 idx, params = sample_params
# --> 189 res = bcm.run(params, include_extras=include_extras)
#     190 return idx, res
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\estival\model.py:156, in BayesianCompartmentalModel.run(self, parameters, include_extras, include_outputs)
#     145 """Run the model for a given set of parameters.
#     146 Note that only parameters specified as priors affect the outputs; other parameters
#     147 are in-filled from the initial arguments supplied to BayesianCompartmentalModel
#    (...)
#     153     ResultsData, an extensible container with derived_outputs as a DataFrame
#     154 """
#     155 run_params = {k: v for k, v in parameters.items() if k in self._model_parameters}
# --> 156 results = self._full_runner._run_func(run_params)
#     158 if include_extras:
#     159     extras = {}
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\jax\_src\pjit.py:245, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     243 @api_boundary
#     244 def cache_miss(*args, **kwargs):
# --> 245   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     246       fun, infer_params_fn, *args, **kwargs)
#     247   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     248   maybe_fastpath_data = _get_fastpath_data(
#     249       executable, out_tree, args_flat, out_flat, attrs_tracked)
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\jax\_src\pjit.py:133, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     131 def _python_pjit_helper(fun, infer_params_fn, *args, **kwargs):
#     132   args_flat, _, params, _, out_tree, _, _, _, arg_names, attrs_tracked = \
# --> 133       infer_params_fn(*args, **kwargs)
#     134   for arg in args_flat:
#     135     dispatch.check_arg(arg)
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\jax\_src\api.py:319, in jit.<locals>.infer_params(*args, **kwargs)
#     310 out_layouts = kwargs.pop('_out_layouts', None)
#     311 pjit_info_args = pjit.PjitInfo(
#     312     fun=fun, in_shardings=in_shardings,
#     313     out_shardings=out_shardings, static_argnums=static_argnums,
#    (...)
#     317     abstracted_axes=abstracted_axes, in_layouts=in_layouts,
#     318     out_layouts=out_layouts)
# --> 319 return pjit.common_infer_params(pjit_info_args, *args, **kwargs)
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\jax\_src\pjit.py:488, in common_infer_params(***failed resolving arguments***)
#     482   in_type = in_avals = tuple(avals)
#     484 canonicalized_in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     485     hashable_pytree(in_shardings), hashable_pytree(in_layouts), in_avals,
#     486     in_tree, resource_env, dbg, device_or_backend_set, True if kwargs else False)
# --> 488 jaxpr, consts, out_shardings, out_layouts_flat, attrs_tracked = _pjit_jaxpr(
#     489     flat_fun, hashable_pytree(out_shardings), hashable_pytree(out_layouts),
#     490     in_type, dbg, device_or_backend_set, HashableFunction(out_tree, closure=()),
#     491     HashableFunction(res_paths, closure=()), inline)
#     493 assert len(explicit_args) == len(canonicalized_in_shardings_flat) == len(in_layouts_flat)
#     495 if config.dynamic_shapes.value:
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\jax\_src\pjit.py:1134, in _pjit_jaxpr(fun, out_shardings_thunk, out_layouts_thunk, in_type, debug_info, device_or_backend_set, out_tree, result_paths, inline)
#    1132 def _pjit_jaxpr(fun, out_shardings_thunk, out_layouts_thunk, in_type, debug_info,
#    1133                 device_or_backend_set, out_tree, result_paths, inline):
# -> 1134   jaxpr, final_consts, out_type, attrs_tracked = _create_pjit_jaxpr(
#    1135       fun, in_type, debug_info, result_paths, IgnoreKey(inline))
#    1136   canonicalized_out_shardings_flat, out_layouts_flat = _check_and_canonicalize_out_shardings(
#    1137       out_shardings_thunk, out_layouts_thunk, out_tree, tuple(out_type),
#    1138       jaxpr.jaxpr.debug_info, device_or_backend_set)
#    1139   return jaxpr, final_consts, canonicalized_out_shardings_flat, out_layouts_flat, attrs_tracked
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\jax\_src\linear_util.py:349, in cache.<locals>.memoized_fun(fun, *args)
#     347   fun.populate_stores(stores)
#     348 else:
# --> 349   ans = call(fun, *args)
#     350   if explain and config.explain_cache_misses.value:
#     351     explain(fun.f, cache is new_cache, cache, key, ans)
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\jax\_src\pjit.py:1073, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1071     attrs_tracked = []
#    1072   else:
# -> 1073     jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    1074         fun, in_type, debug_info=pe_debug)
#    1076 # TODO(dougalm,mattjj): enable debug info with attrs_tracked
#    1077 if not config.dynamic_shapes.value and not attrs_tracked:
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\jax\_src\profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\jax\_src\interpreters\partial_eval.py:2314, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2312 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    2313   main.jaxpr_stack = ()  # type: ignore
# -> 2314   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2315     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2316   del main, fun
#    2317 return jaxpr, out_avals, consts, attrs_tracked
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\jax\_src\interpreters\partial_eval.py:2336, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2334 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2335 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2336 ans = fun.call_wrapped(*in_tracers_)
#    2337 out_tracers = map(trace.full_raise, ans)
#    2338 jaxpr, consts, attrs_tracked = frame.to_jaxpr(out_tracers)
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\jax\_src\linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\summer2\runner\jax\model_impl.py:598, in build_run_model.<locals>.run_model(parameters)
#     597 def run_model(parameters):
# --> 598     static_graph_vals = static_graph_func(parameters=parameters)
#     599     initial_population = calc_initial_pop(static_graph_vals)
#     601     static_flow_weights = jnp.zeros(len(runner.model.flows))
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\computegraph\graph.py:117, in build_callable.<locals>.compute_for_keys(**kwargs)
#     116 def compute_for_keys(**kwargs):
# --> 117     results = compute_from_params(**kwargs)
#     118     return {k: results[k] for k in targets}
#
# File c:\Users\vbui0010\Anaconda3\envs\tbdyn\lib\site-packages\computegraph\graph.py:105, in build_callable.<locals>.compute_from_params(**sources)
#     103         out_p[node] = node_spec.evaluate(**sources)
#     104     except Exception as e:
# --> 105         raise GraphRunError(node, e)
#     107 if include_inputs:
#     108     out_p.update({k: v for k, v in sources.items() if k != "graph_locals"})
#
# GraphRunError: ('parameters.incidence_props_pulmonary', KeyError('incidence_props_pulmonary'))

# %%
def plot_diff(results: Dict[str, Dict[str, pd.DataFrame]], idata: az.InferenceData):
    """
    Plot the differences for cumulative diseased and cumulative deaths between
    'detection only' and 'no covid' scenarios, using only the columns with the 
    lowest and highest values in the last row.

    Args:
        results: Dictionary containing the difference DataFrames for cumulative diseased and deaths.
        idata: InferenceData object containing the posterior parameter values.
    """
    diff_results = results["diff_results"]
    indicators = ["cumulative_diseased_yearly_diff", "cumulative_deaths_yearly_diff"]
    posterior_samples = idata.posterior

    # Create subplots for differences
    fig = make_subplots(
        rows=1, cols=2,
        subplot_titles=["Cumulative Diseased Yearly Difference", "Cumulative Deaths Yearly Difference"]
    )

    for idx, indicator in enumerate(indicators, start=1):
        diff_df = diff_results[indicator]
        last_row = diff_df.iloc[-1]
        min_col = last_row.idxmin()
        max_col = last_row.idxmax()

        # Plot only the min and max columns for differences
        for col in [min_col, max_col]:
            sample_idx = int(col)
            param_info = posterior_samples.isel(sample=sample_idx)
            legend_label = "<br>".join(
                f"{param}: {round(float(value.values), 3)}"
                for param, value in param_info.items()
            )
            fig.add_trace(
                go.Scatter(
                    x=diff_df.index,
                    y=diff_df[col],
                    mode='lines',
                    name=legend_label,
                    line=dict(width=2)
                ),
                row=1,
                col=idx
            )

    # Customize axes
    for i in range(1, 3):
        fig.update_xaxes(title_text="Year", row=1, col=i)
        # fig.update_yaxes(title_text=f"{indicators[i-1].replace('_', ' ').capitalize()} (Difference)", row=1, col=i)

    # Update layout with a central legend at the bottom
    fig.update_layout(
        title="COVID Scenario Differences: Cumulative Diseased and Deaths",
        showlegend=True,
        legend=dict(
            title="Parameter Sets",
            x=0.5,
            y=-0.5,
            xanchor="center",
            orientation="h"
        ),
        height=680,
        template="plotly_white"
    )

    fig.show()

# %%
plot_diff(covid_diff, idata)

# %%
def plot_raw(results: Dict[str, Dict[str, pd.DataFrame]], idata: az.InferenceData):
    """
    Plot the raw results for cumulative diseased and cumulative deaths for each scenario,
    with parameter set details from `idata`. Only the first unique minimum and maximum 
    values are used if there are duplicates. The legend is grouped by scenario name, 
    with each parameter set in columns under each scenario.

    Args:
        results: Dictionary containing raw data for cumulative diseased and deaths for each scenario.
        idata: InferenceData object containing the posterior parameter values.
    """
    scenario_results = results["scenario_results"]
    indicators = ["incidence_raw", "mortality_raw"]
    posterior_samples = idata.posterior

    # Create subplots for raw results
    fig = make_subplots(
        rows=1, cols=2,
        subplot_titles=["Incidence (Raw)", "Mortality (Raw)"]
    )

    for idx, indicator in enumerate(indicators, start=1):
        raw_df_no_covid = scenario_results["no_covid"][indicator]
        raw_df_detection = scenario_results["detection"][indicator]

        # Get only the first occurrence of the min and max columns for each scenario
        min_col_no_covid = raw_df_no_covid.iloc[-1].idxmin()
        max_col_no_covid = raw_df_no_covid.iloc[-1].idxmax()
        
        min_col_detection = raw_df_detection.iloc[-1].idxmin()
        max_col_detection = raw_df_detection.iloc[-1].idxmax()

        # Plot the first unique min and max for No COVID scenario
        for i, col in enumerate([min_col_no_covid, max_col_no_covid]):
            sample_idx = int(col)
            param_info = posterior_samples.isel(sample=sample_idx)
            legend_label = "<br>".join(
                f"{param}: {round(float(value.values), 3)}"
                for param, value in param_info.items()
            )
            fig.add_trace(
                go.Scatter(
                    x=raw_df_no_covid.index,
                    y=raw_df_no_covid[col],
                    mode='lines',
                    name=f"<b>No COVID</b><br>{legend_label}",
                    legendgroup="No COVID",
                    showlegend=(i == 0),
                    line=dict(color='blue', width=2)
                ),
                row=1,
                col=idx
            )

        # Plot the first unique min and max for Detection Only scenario
        for i, col in enumerate([min_col_detection, max_col_detection]):
            sample_idx = int(col)
            param_info = posterior_samples.isel(sample=sample_idx)
            legend_label = "<br>".join(
                f"{param}: {round(float(value.values), 3)}"
                for param, value in param_info.items()
            )
            fig.add_trace(
                go.Scatter(
                    x=raw_df_detection.index,
                    y=raw_df_detection[col],
                    mode='lines',
                    name=f"<b>Detection Only</b><br>{legend_label}",
                    legendgroup="Detection Only",
                    showlegend=(i == 0),
                    line=dict(color='green', width=2)
                ),
                row=1,
                col=idx
            )

    # Customize axes
    for i in range(1, 3):
        fig.update_xaxes(title_text="Year", row=1, col=i)
        fig.update_yaxes(title_text=f"{indicators[i-1].replace('_', ' ').capitalize()} (Raw)", row=1, col=i)

    # Update layout with a structured legend, grouping by scenario name
    fig.update_layout(
        title="COVID Scenario Raw Results: Diseased and Deaths",
        showlegend=True,
        legend=dict(
            title_text="Scenario<br><span style='font-size:12px'>Grouped by scenario with parameter sets in columns</span>",
            orientation="h",
            x=0.5,
            y=-0.5,
            xanchor="center",
            font=dict(size=10),
            traceorder="normal",
            itemwidth=200
        ),
        height=800,
        template="plotly_white"
    )

    fig.show()

# %%
plot_raw(covid_diff, idata)

# %%
def plot_cumulative(results: Dict[str, Dict[str, pd.DataFrame]], idata: az.InferenceData):
    """
    Plot the raw results for cumulative diseased and cumulative deaths for each scenario,
    with parameter set details from `idata`. Only the first unique minimum and maximum 
    values are used if there are duplicates. The legend is grouped by scenario name, 
    with each parameter set in columns under each scenario.

    Args:
        results: Dictionary containing raw data for cumulative diseased and deaths for each scenario.
        idata: InferenceData object containing the posterior parameter values.
    """
    scenario_results = results["scenario_results"]
    indicators = ["cumulative_diseased_yearly", "cumulative_deaths_yearly"]
    posterior_samples = idata.posterior

    # Create subplots for raw results
    fig = make_subplots(
        rows=1, cols=2,
        subplot_titles=["Incidence (Raw)", "Mortality (Raw)"]
    )

    for idx, indicator in enumerate(indicators, start=1):
        raw_df_no_covid = scenario_results["no_covid"][indicator]
        raw_df_detection = scenario_results["detection"][indicator]

        # Get only the first occurrence of the min and max columns for each scenario
        min_col_no_covid = raw_df_no_covid.iloc[-1].idxmin()
        max_col_no_covid = raw_df_no_covid.iloc[-1].idxmax()
        
        min_col_detection = raw_df_detection.iloc[-1].idxmin()
        max_col_detection = raw_df_detection.iloc[-1].idxmax()

        # Plot the first unique min and max for No COVID scenario
        for i, col in enumerate([min_col_no_covid, max_col_no_covid]):
            sample_idx = int(col)
            param_info = posterior_samples.isel(sample=sample_idx)
            legend_label = "<br>".join(
                f"{param}: {round(float(value.values), 3)}"
                for param, value in param_info.items()
            )
            fig.add_trace(
                go.Scatter(
                    x=raw_df_no_covid.index,
                    y=raw_df_no_covid[col],
                    mode='lines',
                    name=f"<b>No COVID</b><br>{legend_label}",
                    legendgroup="No COVID",
                    showlegend=(i == 0),
                    line=dict(color='blue', width=2)
                ),
                row=1,
                col=idx
            )

        # Plot the first unique min and max for Detection Only scenario
        for i, col in enumerate([min_col_detection, max_col_detection]):
            sample_idx = int(col)
            param_info = posterior_samples.isel(sample=sample_idx)
            legend_label = "<br>".join(
                f"{param}: {round(float(value.values), 3)}"
                for param, value in param_info.items()
            )
            fig.add_trace(
                go.Scatter(
                    x=raw_df_detection.index,
                    y=raw_df_detection[col],
                    mode='lines',
                    name=f"<b>Detection Only</b><br>{legend_label}",
                    legendgroup="Detection Only",
                    showlegend=(i == 0),
                    line=dict(color='green', width=2)
                ),
                row=1,
                col=idx
            )

    # Customize axes
    for i in range(1, 3):
        fig.update_xaxes(title_text="Year", row=1, col=i)
        fig.update_yaxes(title_text=f"{indicators[i-1].replace('_', ' ').capitalize()} (Cumulative)", row=1, col=i)

    # Update layout with a structured legend, grouping by scenario name
    fig.update_layout(
        title="COVID Scenario Raw Results: Cumulative Diseased and Deaths",
        showlegend=True,
        legend=dict(
            title_text="Scenario<br><span style='font-size:12px'>Grouped by scenario with parameter sets in columns</span>",
            orientation="h",
            x=0.5,
            y=-0.5,
            xanchor="center",
            font=dict(size=10),
            traceorder="normal",
            itemwidth=200
        ),
        height=800,
        template="plotly_white"
    )

    fig.show()

# %%
plot_cumulative(covid_diff, idata)
